# %% [markdown]
# # BenignIDS v4: course map
# This project connects probability, validation, dimensionality reduction, neural networks, ensembles, and Bayesian optimization to an IDS experiment.
#
# Notation: $X$ is traffic input, $y\in\{0,1\}$ is the target, $y_{score}=P(y=1\mid X)$, and $\tau$ is the decision threshold.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
CONFIG_PATH = PROJECT_ROOT / 'configs/default.yaml'
print(PROJECT_ROOT, CONFIG_PATH)

# %% [markdown]
# ## Scientific questions
# 1. Does masked-token pretraining improve supervised PR-AUC?
# 2. Does the transformer outperform Bayesian-optimized LightGBM?
# 3. How do grid, random, and Bayesian search compare for equal budgets?
# 4. How does $\tau$ alter precision and recall under imbalance?
# 5. How stable are conclusions under label noise and repeated seeds?
