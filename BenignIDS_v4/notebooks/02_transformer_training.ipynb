# %% [markdown]
# # 2. Transformer pretraining and fine-tuning
# Stage A predicts masked traffic tokens without labels. Stage B fine-tunes the encoder to estimate $P(y=1\mid X)$. This is a compact domain transformer, not a general-purpose conversational LLM.

# %%
from pathlib import Path
from benignids.config import load_config
from benignids.transformer_experiment import run_transformer_experiment
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
config = load_config(PROJECT_ROOT / 'configs/default.yaml')
metrics = run_transformer_experiment(config, quick=True)
metrics

# %% [markdown]
# ## Optimization
# Tune representation size, layers, attention heads, dropout, learning rate, masking probability, and class weighting using cross-validation or `X_val` PR-AUC. Never select them from `X_test` performance.
