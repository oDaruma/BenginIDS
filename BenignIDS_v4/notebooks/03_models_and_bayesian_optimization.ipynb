# %% [markdown]
# # 3. Models and optimization
# Compare logistic regression, random forest, LightGBM, grid search, random search, Bayesian optimization, soft voting, and stacking. Bayesian-optimized LightGBM is the principal non-transformer baseline.

# %%
from pathlib import Path
from benignids.config import load_config
from benignids.experiment import run_experiment
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
config = load_config(PROJECT_ROOT / 'configs/default.yaml')
comparison = run_experiment(config, quick=True)
comparison[['model', 'method', 'pr_auc', 'precision', 'recall', 'f1', 'fit_seconds']]

# %% [markdown]
# ## Exploration and exploitation
# Bayesian optimization models the objective over hyperparameters $\theta$. Its acquisition function balances predicted improvement (exploitation) with uncertainty (exploration). Use identical CV folds and comparable trial budgets.
